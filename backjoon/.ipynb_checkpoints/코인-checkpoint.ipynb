# %%
# N: 동전의 종류 K:최종합
N,K = map(int,input().split())
array_coin = []
cnt = 0 

## 코인 종류 array_coin에 저장
for i in range(N):
    array_coin.append(int(input()))

## 큰 순으로 정렬    
array_coin.reverse()

## 몇번이 최소인지 구하는 방식
for j in array_coin:
    cnt += K//j
    K %= j

print(cnt)
# Out:
# 10 4790
# 1
# 5
# 10
# 50
# 100
# 500
# 1000
# 5000
# 10000
# 50000
# 12

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 array_coin = []
#       2 for i in range(5):
# ----> 3     array_coin[i] = 3
#
# IndexError: list assignment index out of range
